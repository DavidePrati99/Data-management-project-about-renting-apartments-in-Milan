# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install pandas-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.0/353.0 kB 30.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 10.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 40.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 kB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 25.0 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=0deb4fb92453e84c60b9fa2a9eb615baa33fd7112555b96503437c91051e4941
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: wordcloud
# ...

# %%
import pandas_profiling
# Out:
# <ipython-input-3-6a00893fb3e1>:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# ## Comuni

# %%
path1="/content/drive/MyDrive/Progetto DATA MAN/csv di esportazione dati/comuni_202307111626.csv"
comuni= pd.read_csv(path1, sep= ",")#, parse_dates=['data'])
comuni.shape
# Out:
# (228, 18)

# %%
comuni[['nome','comune_appartenenza','vendita_minima(€/mese)','vendita_massima(€/mese)',	'affitto_minimo(€/mese)',	'affitto_massimo(€/mese)','popolazione']].head(10)

# %%
report_comuni = pandas_profiling.ProfileReport(comuni)
report_comuni
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ---

# %% [markdown]
# ## Affitti

# %%
path2="/content/drive/MyDrive/Progetto DATA MAN/csv di esportazione dati/affitti_202307081614.csv"
affitti = pd.read_csv(path2, sep= ",")#, parse_dates=['data'])
affitti.shape

# %%
a=affitti[affitti["comuneId"]==2]
a

# %%
report_affitti = pandas_profiling.ProfileReport(affitti)
report_affitti

# %%
latitudine_min = affitti["latitudine"].min()
latitudine_max = affitti["latitudine"].max()
longitudine_min = affitti["longitudine"].min()
longitudine_max = affitti["longitudine"].max()

print("minimo:", latitudine_min, longitudine_min)
print("massimo:", latitudine_max, longitudine_max)

# %%
affitti_sorted_lat = affitti.sort_values("latitudine")
affitti_sorted_lat[['id','latitudine','longitudine']].head()

# %%
affitti_sorted_long = affitti.sort_values("longitudine")
affitti_sorted_long[['id','latitudine','longitudine']].tail()

# %%
inaccurate_record = affitti.iloc[5999]
inaccurate_record

# %% [markdown]
# ---

# %% [markdown]
# ## Mezzi Pubblici

# %%
path3="/content/drive/MyDrive/Progetto DATA MAN/csv di esportazione dati/mezzi_pubblici_202307081614.csv"
mezzi_pubblici = pd.read_csv(path3, sep= ",")#, parse_dates=['data'])
mezzi_pubblici.shape

# %%
report_mezzi_pubblici = pandas_profiling.ProfileReport(mezzi_pubblici)
report_mezzi_pubblici

# %%
latitudine_min = mezzi_pubblici["latitudine"].min()
latitudine_max = mezzi_pubblici["latitudine"].max()
longitudine_min = mezzi_pubblici["longitudine"].min()
longitudine_max = mezzi_pubblici["longitudine"].max()

print("minimo:", latitudine_min, longitudine_min)
print("massimo:", latitudine_max, longitudine_max)
